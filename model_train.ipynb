# %%
# !pip install ultralytics==8.0.26

# %%
from ultralytics import YOLO

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !yolo task=detect mode=train model=yolov8l.pt data= /content/drive/MyDrive/ColabNotebooks/ANPR/data.yaml epochs=50 imgsz=640
# Out:
# Ultralytics YOLOv8.0.26 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !scp -r /content/runs '/content/drive/MyDrive/ColabNotebooks/ANPR/'
